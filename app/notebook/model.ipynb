# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\Projects\\aave_credit_score\\app\output\\wallet_features.csv")

# %%
df
# Out:
#                                       userWallet  n_txns  n_deposits  \
# 0     0x00000000001accfa9cef68cf5371a23025b6d4b6       1           1
# 1     0x000000000051d07a4fb3bd10121a343d85818da6       1           1
# 2     0x000000000096026fb41fc39f9875d164bd82e2dc       2           2
# 3     0x0000000000e189dd664b9ab08a33c4839953852c      17           0
# 4     0x0000000002032370b971dabd36d72f3e5a7bf1ee     399         250
# ...                                          ...     ...         ...
# 3492  0x06185db89f5c8ef5e5a0abc95c5cb69b54c33f30       1           1
# 3493  0x06189341e523a52ae10c4bd4a7774371fac1b249       7           4
# 3494  0x0618c450370822c5cb25ec143a3008230d8e2c12       5           1
# 3495  0x0618e615c8c9b5efc8c8eadc68be7182bdc455e2      22          13
# 3496  0x06192f889f17bf2aff238d08d8c26cbcfcc7b45a     183          53
#
#       n_borrows  n_repays  n_redeems  n_liquidations  total_deposited_usd  \
# ...
